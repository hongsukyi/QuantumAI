# %% [markdown]
# # lab1: 회로 생성과 실행
# ### 양자 머신러닝 첫 실습 (PennyLane · Colab)
#
# **학습 목표**
# 1. QNode로 양자 회로를 만들고 텍스트/그림으로 시각화한다.
# 2. 해석적(analytic) 결과와 유한 shots 측정 결과의 차이를 이해한다.
# 3. 통계 오차가 shots 수 N에 대해 1/√N 로 줄어드는 것을 직접 확인한다.
#
# > 예제 회로: `RX(θ)|0⟩` 측정 후 `⟨Z⟩ = cos θ`. 이론값을 아는 회로라
# > "왜 이 값이 나오는지"를 스스로 검증할 수 있다.

# %%
# !pip install -q pennylane


import pennylane as qml
from pennylane import numpy as np
import numpy as std_np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# ---- 공통 설정 ----
SEED = 1234                    # 재현성: shot 샘플링 난수를 고정
theta = np.pi / 3              # 회전각 (cos(pi/3) = 0.5)
theory = float(np.cos(theta))  # 이론값 (해석적 정답)

# seed를 device에 걸어야 실행할 때마다 같은 결과가 나온다.
dev = qml.device("default.qubit", wires=1, seed=SEED)

# %%
# %%
# ===========================================================
#  1-1: 기본 회로 생성 & 시각화
# ===========================================================
print("=" * 60)
print("lab1-1: 기본 회로 & 시각화")
print("=" * 60)


@qml.qnode(dev)
def circuit(angle):
    qml.RX(angle, wires=0)
    return qml.expval(qml.PauliZ(0))


# 텍스트 회로도
print("\n[텍스트 회로도]")
print(qml.draw(circuit, decimals=3)(theta))

# matplotlib 회로도
fig, ax = qml.draw_mpl(circuit, decimals=3, style="black_white")(theta)
fig.suptitle("lab1: RX circuit", fontsize=14)
plt.tight_layout()
fig.savefig("./lab1a.png", dpi=300, bbox_inches="tight")
plt.show()

# 해석적 실행 (노이즈/샘플링 없는 정확한 값)
result = float(circuit(theta))
print(f"\n해석적 결과   : {result:.6f}")
print(f"이론값 cos(θ) : {theory:.6f}")
print(f"오차          : {abs(result - theory):.2e}")
# Out:
# ============================================================
# lab1-1: 기본 회로 & 시각화
# ============================================================
#
# [텍스트 회로도]
# 0: ──RX(1.047)─┤  <Z>
# 해석적 결과   : 0.500000
# 이론값 cos(θ) : 0.500000
# 오차          : 1.11e-16

# %%
# %%
# ===========================================================
#  1-2: Shots vs Analytic
# ===========================================================
print("\n" + "=" * 60)
print("lab1-2: Shots vs Analytic")
print("=" * 60)

shot_counts = [128, 512, 1024]
results_by_shots = {}

# 최신 API: qml.set_shots(qnode, shots=s) 로 측정 횟수를 지정한다.
# (예전의 circuit(theta, shots=s) 나 device(shots=...) 방식은 deprecated)
for s in shot_counts:
    shot_circuit = qml.set_shots(circuit, shots=s)
    val = float(shot_circuit(theta))
    results_by_shots[s] = val
    print(f"  shots={s:>5d}  ->  <Z> = {val:+.6f}  (오차 {abs(val - theory):.4f})")

# 기댓값 수렴 그림
fig, ax = plt.subplots(figsize=(7, 5))
ax.semilogx(list(results_by_shots.keys()),
            list(results_by_shots.values()), "o-", label="measured")
ax.axhline(y=theory, color="r", ls="--", label=f"theory = {theory:.4f}")
ax.set_xlabel("Shots")
ax.set_ylabel("<Z>")
ax.set_title("lab1: expectation value convergence")
ax.legend()
ax.grid(True, alpha=0.3)
plt.tight_layout()
fig.savefig("./lab1b.png", dpi=300, bbox_inches="tight")
plt.show()

print("\n주의: 단일 실행이라 shots가 늘어도 오차가 들쭉날쭉할 수 있다.")
print("      경향을 제대로 보려면 다음 1-3처럼 여러 번 반복해 평균내야 한다.")
# Out:
# ============================================================
# lab1-2: Shots vs Analytic
# ============================================================
#   shots=  128  ->  <Z> = +0.484375  (오차 0.0156)
#   shots=  512  ->  <Z> = +0.515625  (오차 0.0156)
#   shots= 1024  ->  <Z> = +0.511719  (오차 0.0117)
# 주의: 단일 실행이라 shots가 늘어도 오차가 들쭉날쭉할 수 있다.
#       경향을 제대로 보려면 다음 1-3처럼 여러 번 반복해 평균내야 한다.

# %%
# ===========================================================
#  1-3: 통계 오차의 1/sqrt(N) 스케일링  (log-log)
# ===========================================================
print("\n" + "=" * 60)
print("lab1-3: 오차 스케일링 1/sqrt(N)")
print("=" * 60)

# 넓은 범위 + 각 shots마다 R회 반복해 |오차| 평균 -> 경향이 선명해진다.
shot_scan = [16, 64, 256, 1024, 4096, 16384]
R = 200

mean_err = []
for s in shot_scan:
    errs = [abs(float(qml.set_shots(circuit, shots=s)(theta)) - theory)
            for _ in range(R)]
    m = std_np.mean(errs)
    mean_err.append(m)
    print(f"  shots={s:>6d}  ->  mean|error| = {m:.5f}")

# log-log 기울기 추정 (이론상 -0.5 여야 함)
slope = std_np.polyfit(std_np.log10(shot_scan), std_np.log10(mean_err), 1)[0]
print(f"\nlog-log 기울기 = {slope:.3f}  (이론값 -0.5)")

# 1/sqrt(N) 기준선과 함께 그리기
ref = mean_err[0] * (shot_scan[0] / std_np.array(shot_scan)) ** 0.5
fig, ax = plt.subplots(figsize=(7, 5))
ax.loglog(shot_scan, mean_err, "o-", label=f"measured error (mean of {R} runs)")
ax.loglog(shot_scan, ref, "r--", label=r"$1/\sqrt{N}$ reference")
ax.set_xlabel("Shots (N)")
ax.set_ylabel("mean |error|")
ax.set_title(r"lab1: statistical error scaling ($1/\sqrt{N}$)")
ax.legend()
ax.grid(True, which="both", alpha=0.3)
plt.tight_layout()
fig.savefig("./lab1c.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# ============================================================
# lab1-3: 오차 스케일링 1/sqrt(N)
# ============================================================
#   shots=    16  ->  mean|error| = 0.16937
#   shots=    64  ->  mean|error| = 0.07953
#   shots=   256  ->  mean|error| = 0.04664
#   shots=  1024  ->  mean|error| = 0.02137
#   shots=  4096  ->  mean|error| = 0.01003
#   shots= 16384  ->  mean|error| = 0.00515
#
# log-log 기울기 = -0.504  (이론값 -0.5)
